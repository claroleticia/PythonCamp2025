# %% [markdown]
# # APIs

# %% [markdown]
# #### What is an API?

# %% [markdown]
# API stands for:
# - Application (a piece of software, a computer program, or a server)
# - Programming (what you’re doing with python)
# - Interface (how you’re communicating)

# %% [markdown]
# An API is a mechanism that allows two software components to communicate, via a set of definitions and protocols.

# %% [markdown]
# An application known as the *client* is able to send *requests* for information to another application, known as the *server*, who will send back *responses* containing information.

# %% [markdown]
# * Pre-determined parameters required in a request, and the pre-determined structure of a response vary widely across APIs.
# * APIs vary widely in many ways. Important ones to consider:
#     * Is it public?
#     * Does it require authenitacion?
#     * Does it have a cost?
#     * What types of constraints on requests?

# %% [markdown]
# Paraphrased from: https://aws.amazon.com/what-is/api/

# %% [markdown]
# ##### A concrete example

# %% [markdown]
# ##### How Developers Use APIs

# %% [markdown]
# ###### Weather App

# %% [markdown]
# * The app requires its users' local weather information to display back to them
# * Worldwide weather databases like the CDO allows the public (researchers and developers) to use the API
# * Devs can use this to render the weather views back to users including accurate weather info

# %% [markdown]
# ###### Camera App

# %% [markdown]
# - The app’s functionality requires photography (think SnapChat)
# - iPhone devs already made camera software & efficient translations of inputs to outputs
# - Devs can use that software instead of writing it from scratch! (gains from trade)
# - Use the iPhone camera API to embed photography functions in your app
# - When Apple upgrades the camera software, your app benefits from the improvements
# - Another non-technical explanation: https://www.howtogeek.com/343877/what-is-an-api/

# %% [markdown]
# ##### How Social Scientists Use APIs

# %% [markdown]
# ###### Weather & Public Opinion

# %% [markdown]
# * Egan, Patrick J., and Megan Mullin. “Turning Personal Experience into Political Attitudes: The Effect of Local Weather on Americans’ Perceptions about Global Warming.” The Journal of Politics 74, no. 3 (2012): 796–809. https://doi.org/10.1017/s0022381612000448.
#     * Connected local weather data from CDO to Pew Research survey responses on how Americans perceive Global Warming

# %% [markdown]
# As Tools:
# 1. Google Cloud Speech API
# 2. Microsoft Azure Emotion API

# %% [markdown]
# As Data:
# 1. Census
# 2. GoogleMaps
# 3. Twitter/Meta/Reddit/etc.
# 4. FEC
# 5. Legislative data (e.g., UK and Brazil Parliaments)

# %% [markdown]
# ##### All APIs are different, and each has its own learning curve.

# %% [markdown]
# For this course, we are only using python wrappers for APIs, but R also offers API wrappers. If you prefer to use R, look for these prior to writing your code.

# %% [markdown]
# ### 1. Spotify API

# %% [markdown]
# `Spotipy` is a lightweight python library for the Spotify Web API.
#
# With `Spotipy`, you get full access to all of the music data provided by the Spotify platform.
#
#
# Here is the documentation: https://spotipy.readthedocs.io/en/2.22.1/

# %% [markdown]
# 1. Installation

# %% [markdown]
# * Run the following in a Jupyter cell

# %%
#!pip install spotipy --upgrade
# Out:
# Collecting spotipy
#   Downloading spotipy-2.25.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Downloading redis-6.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: requests>=2.25.0 in /Users/claro/Library/Python/3.13/lib/python/site-packages (from spotipy) (2.32.4)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/claro/Library/Python/3.13/lib/python/site-packages (from spotipy) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/claro/Library/Python/3.13/lib/python/site-packages (from requests>=2.25.0->spotipy) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/claro/Library/Python/3.13/lib/python/site-packages (from requests>=2.25.0->spotipy) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/claro/Library/Python/3.13/lib/python/site-packages (from requests>=2.25.0->spotipy) (2025.8.3)
# Downloading spotipy-2.25.1-py3-none-any.whl (31 kB)
# Downloading redis-6.4.0-py3-none-any.whl (279 kB)
# Installing collected packages: redis, spotipy
# Successfully installed redis-6.4.0 spotipy-2.25.1
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# 2. Get your credentials
#     - Go to: https://developer.spotify.com/dashboard
#     - Log in (or create a Spotify account if you don't already have one)
#     - Create an app (You don't need the Redirect URL, but just put down some random website)
#     - Request an access token: get your client ID and client secret

# %% [markdown]
# * It is best practice to store these in a separate file, but for demonstration we will just use this

# %%
client_id = 'edit with your client id'
client_secret = 'edit with your client secret'

# %% [markdown]
# 3. Import libraries

# %%
#import sys
#print(sys.executable)

#endpoint: a specific address in the API where you ask for data.
# Out:
# /usr/local/bin/python3

# %%
#!pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.1.1
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %% [markdown]
# 4. Use your credentials

# %%
import os
from dotenv import load_dotenv

load_dotenv()

client_id = os.getenv("SPOTIFY_CLIENT_ID")
client_secret = os.getenv("SPOTIFY_CLIENT_SECRET")

if not client_id or not client_secret:
    raise RuntimeError("Spotify_API_KEY not set in environment")

# %%
spotify = spotipy.Spotify(client_credentials_manager=
                          SpotifyClientCredentials(client_id=client_id,
                                                   client_secret=client_secret))

# %% [markdown]
# ##### An example usecase: Let's search for Taylor Swift and find all her albums

# %% [markdown]
# 1. Find her identifier

# %% [markdown]
# * Copy from the URL associated with artist's page on Spotify:
#     * https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02

# %%
taylor_uri = '06HL4z0CvFAxyc27GXpf02'

# %% [markdown]
# 2. Use the method `.artist_albums()` to find her albums

# %%
results = spotify.artist_albums(taylor_uri, album_type='album')

# %% [markdown]
# Let's check the output we got from `results`

# %%
print(results)
# Out:
# {'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02/albums?offset=0&limit=20&include_groups=album', 'limit': 20, 'next': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02/albums?offset=20&limit=20&include_groups=album', 'offset': 0, 'previous': None, 'total': 30, 'items': [{'album_type': 'album', 'total_tracks': 31, 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'external_urls': {'spotify': 'https://open.spotify.com/album/5H7ixXZfsNMGbIE5OBSpcb'}, 'href': 'https://api.spotify.com/v1/albums/5H7ixXZfsNMGbIE5OBSpcb', 'id': '5H7ixXZfsNMGbIE5OBSpcb', 'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2738ecc33f195df6aa257c39eaa', 'height': 640, 'width': 640}, {'url': 'https://i.scdn.co/image/ab67616d00001e028ecc33f195df6aa257c39eaa', 'height': 300, 'width': 300}, {'url': 'https://i.scdn.co/image/ab67616d000048518ecc33f195df6aa257c39eaa', 'height': 64, 'width': 64}], 'name': 'THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY', 'release_date': '2024-04-19', 'release_date_precision': 'day', 'type': 'album', 'uri': 'spotify:album:5H7ixXZfsNMGbIE5OBSpcb', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'}, 'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02', 'id': '06HL4z0CvFAxyc27GXpf02', 'name': 'Taylor Swift', 'type': 'artist', 'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}], 'album_group': 'album'}, {'album_type': 'album', 'total_tracks': 16, 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'external_urls': {'spotify': 'https://open.spotify.com/album/1Mo4aZ8pdj6L1jx8zSwJnt'}, 'href': 'https://api.spotify.com/v1/albums/1Mo4aZ8pdj6L1jx8zSwJnt', 'id': '1Mo4aZ8pdj6L1jx8zSwJnt', 'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2735076e4160d018e378f488c33', 'height': 640, 'width': 640}, {'url': 'https://i.scdn.co/image/ab67616d00001e025 ...

# %% [markdown]
# What is the data type?

# %%
type(results)
# Out:
# dict

# %% [markdown]
# What are the keys of this dictionary?

# %%
results.keys()
# Out:
# dict_keys(['href', 'limit', 'next', 'offset', 'previous', 'total', 'items'])

# %% [markdown]
# Which of these stores the name of the album?

# %%
albums = results['items']
albums
# Out:
# [{'album_type': 'album',
#   'total_tracks': 31,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5H7ixXZfsNMGbIE5OBSpcb'},
#   'href': 'https://api.spotify.com/v1/albums/5H7ixXZfsNMGbIE5OBSpcb',
#   'id': '5H7ixXZfsNMGbIE5OBSpcb',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2738ecc33f195df6aa257c39eaa',
#     'height': 640,
#     'width': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e028ecc33f195df6aa257c39eaa',
#     'height': 300,
#     'width': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d000048518ecc33f195df6aa257c39eaa',
#     'height': 64,
#     'width': 64}],
#   'name': 'THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY',
#   'release_date': '2024-04-19',
#   'release_date_precision': 'day',
#   'type': 'album',
#   'uri': 'spotify:album:5H7ixXZfsNMGbIE5OBSpcb',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'album_group': 'album'},
#  {'album_type': 'album',
#   'total_tracks': 16,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1Mo4aZ8pdj6L1jx8zSwJnt'},
#   'href': 'https://api.spotify.com/v1/albums/1Mo4aZ8pdj6L1jx8zSwJnt',
#   'id': '1Mo4aZ8pdj6L1jx8zSwJnt',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2735076e4160d018e378f488c33',
#     'height': 640,
#     'width': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e025076e4160d018e378f488c33',
#     'height': 300,
#     'width': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d000048515076e4160d018e378f488c33',
#     'height': 64,
#     'width': 64}],
#   'name': 'THE TORTURED POETS DEPARTMENT',
#   'release_date': '2024-04-18',
#   'release_date_precision': 'day',
#   'type': 'album',
#   'uri': 'spotify:album:1Mo4aZ8pdj6L1jx8zSwJnt',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'album_group': 'album'},
#  {'album_type': 'album',
#   'total_tracks': 22,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1o59UpKw81iHR0HPiSkJR0'},
#   'href': 'https://api.spotify.com/v1/albums/1o59UpKw81iHR0HPiSkJR0',
#   'id': '1o59UpKw81iHR0HPiSkJR0',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273dc2bacae1dca83d26e2b1949',
#     'height': 640,
#     'width': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e02dc2bacae1dca83d26e2b1949',
#     'height': 300,
#     'width': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d00004851dc2bacae1dca83d26e2b1949',
#     'height': 64,
#     'width': 64}],
#   'name': "1989 (Taylor's Version) [Deluxe]",
#   'release_date': '2023-10-27',
#   'release_date_precision': 'day',
#   'type': 'album',
#   'uri': 'spotify:album:1o59UpKw81iHR0HPiSkJR0',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'album_group': 'album'},
#  {'album_type': 'album',
#   'total_tracks': 21,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/64LU4c1nfjz1t4VnGhagcg'},
#   'href': 'https://api.spotify.com/v1/albums/64LU4c1nfjz1t4VnGhagcg',
#   'id': '64LU4c1nfjz1t4VnGhagcg',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273904445d70d04eb24d6bb79ac',
#     'height': 640,
#     'width': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e02904445d70d04eb24d6bb79ac',
#     'height': 300,
#     'width': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d00004851904445d70d04eb24d6bb79ac',
#     'height': 64,
#     'width': 64}],
#   'name': "1989 (Taylor's Version)",
#   'release_date': '2023-10-26',
#   'release_date_precision': 'day',
#   'type': 'album',
#   'uri': 'spotify:album:64LU4c1nfjz1t4VnGhagcg',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'album_group': 'album'},
#  {'album_type': 'album',
#   'total_tracks': 22,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5AEDGbliTTfjOB8TSm1sxt'},
#   'href': 'https://api.spotify.com/v1/albums/5AEDGbliTTfjOB8TSm1sxt',
#   'id': '5AEDGbliTTfjOB8TSm1sxt',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2730b04da4f224b51ff86e0a481',
#     'height': 640,
#     'width': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e020b04da4f224b51ff86e0a481',
#     'height': 300,
#     'width': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d000048510b04da4f224b51ff86e0a481',
#     'height': 64,
#     'width': 64}],
#   'name': "Speak Now (Taylor's Version)",
#   'release_date': '2023-07-07',
#   'release_date_precision': 'day',
#   'type': 'album',
#   'uri': 'spotify:album:5AEDGbliTTfjOB8TSm1sxt',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'album_group': 'album'},
#  {'album_type': 'album',
#   'total_tracks': 23,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1fnJ7k0bllNfL1kVdNVW1A'},
#   'href': 'https://api.spotify.com/v1/albums/1fnJ7k0bllNfL1kVdNVW1A',
#   'id': '1fnJ7k0bllNfL1kVdNVW1A',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273fa747621a53c8e2cc436dee0',
#     'height': 640,
#     'width': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e02fa747621a53c8e2cc436dee0',
#     'height': 300,
#     'width': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d00004851fa747621a53c8e2cc436dee0',
#     'height': 64,
#     'width': 64}],
#   'name': 'Midnights (The Til Dawn Edition)',
#   'release_date': '2023-05-26',
#   'release_date_precision': 'day',
#   'type': 'album',
#   'uri': 'spotify:album:1fnJ7k0bllNfL1kVdNVW1A',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'album_group': 'album'},
#  {'album_type': 'album',
#   'total_tracks': 20,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3lS1y25WAhcqJDATJK70Mq'},
#   'href': 'https://api.spotify.com/v1/albums/3lS1y25WAhcqJDATJK70Mq',
#   'id': '3lS1y25WAhcqJDATJK70Mq',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273e0b60c608586d88252b8fbc0',
#     'height': 640,
#     'width': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e02e0b60c608586d88252b8fbc0',
#     'height': 300,
#     'width': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d00004851e0b60c608586d88252b8fbc0',
#     'height': 64,
#     'width': 64}],
#   'name': 'Midnights (3am Edition)',
#   'release_date': '2022-10-22',
#   'release_date_precision': 'day',
#   'type': 'album',
#   'uri': 'spotify:album:3lS1y25WAhcqJDATJK70Mq',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'album_group': 'album'},
#  {'album_type': 'album',
#   'total_tracks': 13,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/151w1FgRZfnKZA9FEcg9Z3'},
#   'href': 'https://api.spotify.com/v1/albums/151w1FgRZfnKZA9FEcg9Z3',
#   'id': '151w1FgRZfnKZA9FEcg9Z3',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273bb54dde68cd23e2a268ae0f5',
#     'height': 640,
#     'width': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e02bb54dde68cd23e2a268ae0f5',
#     'height': 300,
#     'width': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d00004851bb54dde68cd23e2a268ae0f5',
#     'height': 64,
#     'width': 64}],
#   'name': 'Midnights',
#   'release_date': '2022-10-21',
#   'release_date_precision': 'day',
#   'type': 'album',
#   'uri': 'spotify:album:151w1FgRZfnKZA9FEcg9Z3',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'album_group': 'album'},
#  {'album_type': 'album',
#   'total_tracks': 30,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6kZ42qRrzov54LcAk4onW9'},
#   'href': 'https://api.spotify.com/v1/albums/6kZ42qRrzov54LcAk4onW9',
#   'id': '6kZ42qRrzov54LcAk4onW9',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273318443aab3531a0558e79a4d',
#     'height': 640,
#     'width': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e02318443aab3531a0558e79a4d',
#     'height': 300,
#     'width': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d00004851318443aab3531a0558e79a4d',
#     'height': 64,
#     'width': 64}],
#   'name': "Red (Taylor's Version)",
#   'release_date': '2021-11-12',
#   'release_date_precision': 'day',
#   'type': 'album',
#   'uri': 'spotify:album:6kZ42qRrzov54LcAk4onW9',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'album_group': 'album'},
#  {'album_type': 'album',
#   'total_tracks': 26,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4hDok0OAJd57SGIT8xuWJH'},
#   'href': 'https://api.spotify.com/v1/albums/4hDok0OAJd57SGIT8xuWJH',
#   'id': '4hDok0OAJd57SGIT8xuWJH',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273a48964b5d9a3d6968ae3e0de',
#     'height': 640,
#     'width': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e02a48964b5d9a3d6968ae3e0de',
#     'height': 300,
#     'width': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d00004851a48964b5d9a3d6968ae3e0de',
#     'height': 64,
#     'width': 64}],
#   'name': "Fearless (Taylor's Version)",
#   'release_date': '2021-04-09',
#   'release_date_precision': 'day',
#   'type': 'album',
#   'uri': 'spotify:album:4hDok0OAJd57SGIT8xuWJH',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'album_group': 'album'},
#  {'album_type': 'album',
#   'total_tracks': 17,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6AORtDjduMM3bupSWzbTSG'},
#   'href': 'https://api.spotify.com/v1/albums/6AORtDjduMM3bupSWzbTSG',
#   'id': '6AORtDjduMM3bupSWzbTSG',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b27390fd9741e1838115cd90b3b6',
#     'height': 640,
#     'width': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e0290fd9741e1838115cd90b3b6',
#     'height': 300,
#     'width': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d0000485190fd9741e1838115cd90b3b6',
#     'height': 64,
#     'width': 64}],
#   'name': 'evermore (deluxe version)',
#   'release_date': '2021-01-07',
#   'release_date_precision': 'day',
#   'type': 'album',
#   'uri': 'spotify:album:6AORtDjduMM3bupSWzbTSG',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'album_group': 'album'},
#  {'album_type': 'album',
#   'total_tracks': 15,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2Xoteh7uEpea4TohMxjtaq'},
#   'href': 'https://api.spotify.com/v1/albums/2Xoteh7uEpea4TohMxjtaq',
#   'id': '2Xoteh7uEpea4TohMxjtaq',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b27333b8541201f1ef38941024be',
#     'height': 640,
#     'width': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e0233b8541201f1ef38941024be',
#     'height': 300,
#     'width': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d0000485133b8541201f1ef38941024be',
#     'height': 64,
#     'width': 64}],
#   'name': 'evermore',
#   'release_date': '2020-12-11',
#   'release_date_precision': 'day',
#   'type': 'album',
#   'uri': 'spotify:album:2Xoteh7uEpea4TohMxjtaq',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'album_group': 'album'},
#  {'album_type': 'album',
#   'total_tracks': 34,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0PZ7lAru5FDFHuirTkWe9Z'},
#   'href': 'https://api.spotify.com/v1/albums/0PZ7lAru5FDFHuirTkWe9Z',
#   'id': '0PZ7lAru5FDFHuirTkWe9Z',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273045514e3ed4e1767a7c3ece5',
#     'height': 640,
#     'width': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e02045514e3ed4e1767a7c3ece5',
#     'height': 300,
#     'width': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d00004851045514e3ed4e1767a7c3ece5',
#     'height': 64,
#     'width': 64}],
#   'name': 'folklore: the long pond studio sessions (from the Disney+ special) [deluxe edition]',
#   'release_date': '2020-11-25',
#   'release_date_precision': 'day',
#   'type': 'album',
#   'uri': 'spotify:album:0PZ7lAru5FDFHuirTkWe9Z',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'album_group': 'album'},
#  {'album_type': 'album',
#   'total_tracks': 17,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1pzvBxYgT6OVwJLtHkrdQK'},
#   'href': 'https://api.spotify.com/v1/albums/1pzvBxYgT6OVwJLtHkrdQK',
#   'id': '1pzvBxYgT6OVwJLtHkrdQK',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273c288028c2592f400dd0b9233',
#     'height': 640,
#     'width': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e02c288028c2592f400dd0b9233',
#     'height': 300,
#     'width': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d00004851c288028c2592f400dd0b9233',
#     'height': 64,
#     'width': 64}],
#   'name': 'folklore (deluxe version)',
#   'release_date': '2020-08-18',
#   'release_date_precision': 'day',
#   'type': 'album',
#   'uri': 'spotify:album:1pzvBxYgT6OVwJLtHkrdQK',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'album_group': 'album'},
#  {'album_type': 'album',
#   'total_tracks': 16,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2fenSS68JI1h4Fo296JfGr'},
#   'href': 'https://api.spotify.com/v1/albums/2fenSS68JI1h4Fo296JfGr',
#   'id': '2fenSS68JI1h4Fo296JfGr',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b27395f754318336a07e85ec59bc',
#     'height': 640,
#     'width': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e0295f754318336a07e85ec59bc',
#     'height': 300,
#     'width': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d0000485195f754318336a07e85ec59bc',
#     'height': 64,
#     'width': 64}],
#   'name': 'folklore',
#   'release_date': '2020-07-24',
#   'release_date_precision': 'day',
#   'type': 'album',
#   'uri': 'spotify:album:2fenSS68JI1h4Fo296JfGr',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'album_group': 'album'},
#  {'album_type': 'album',
#   'total_tracks': 18,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq'},
#   'href': 'https://api.spotify.com/v1/albums/1NAmidJlEaVgA3MpcPFYGq',
#   'id': '1NAmidJlEaVgA3MpcPFYGq',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273e787cffec20aa2a396a61647',
#     'height': 640,
#     'width': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e02e787cffec20aa2a396a61647',
#     'height': 300,
#     'width': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d00004851e787cffec20aa2a396a61647',
#     'height': 64,
#     'width': 64}],
#   'name': 'Lover',
#   'release_date': '2019-08-23',
#   'release_date_precision': 'day',
#   'type': 'album',
#   'uri': 'spotify:album:1NAmidJlEaVgA3MpcPFYGq',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'album_group': 'album'},
#  {'album_type': 'album',
#   'total_tracks': 15,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1MHuZZrGT36cXLxAQ5cLP3'},
#   'href': 'https://api.spotify.com/v1/albums/1MHuZZrGT36cXLxAQ5cLP3',
#   'id': '1MHuZZrGT36cXLxAQ5cLP3',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b27305fd6906725e3f12544c2d04',
#     'height': 640,
#     'width': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e0205fd6906725e3f12544c2d04',
#     'height': 300,
#     'width': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d0000485105fd6906725e3f12544c2d04',
#     'height': 64,
#     'width': 64}],
#   'name': 'Taylor Swift Karaoke: reputation',
#   'release_date': '2018-03-09',
#   'release_date_precision': 'day',
#   'type': 'album',
#   'uri': 'spotify:album:1MHuZZrGT36cXLxAQ5cLP3',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'album_group': 'album'},
#  {'album_type': 'album',
#   'total_tracks': 15,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6DEjYFkNZh67HP7R9PSZvv'},
#   'href': 'https://api.spotify.com/v1/albums/6DEjYFkNZh67HP7R9PSZvv',
#   'id': '6DEjYFkNZh67HP7R9PSZvv',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273da5d5aeeabacacc1263c0f4b',
#     'height': 640,
#     'width': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e02da5d5aeeabacacc1263c0f4b',
#     'height': 300,
#     'width': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d00004851da5d5aeeabacacc1263c0f4b',
#     'height': 64,
#     'width': 64}],
#   'name': 'reputation',
#   'release_date': '2017-11-10',
#   'release_date_precision': 'day',
#   'type': 'album',
#   'uri': 'spotify:album:6DEjYFkNZh67HP7R9PSZvv',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'album_group': 'album'},
#  {'album_type': 'album',
#   'total_tracks': 46,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1MPAXuTVL2Ej5x0JHiSPq8'},
#   'href': 'https://api.spotify.com/v1/albums/1MPAXuTVL2Ej5x0JHiSPq8',
#   'id': '1MPAXuTVL2Ej5x0JHiSPq8',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b27363d77f99117b28af9f656918',
#     'height': 640,
#     'width': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e0263d77f99117b28af9f656918',
#     'height': 300,
#     'width': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d0000485163d77f99117b28af9f656918',
#     'height': 64,
#     'width': 64}],
#   'name': 'reputation Stadium Tour Surprise Song Playlist',
#   'release_date': '2017-11-09',
#   'release_date_precision': 'day',
#   'type': 'album',
#   'uri': 'spotify:album:1MPAXuTVL2Ej5x0JHiSPq8',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'album_group': 'album'},
#  {'album_type': 'album',
#   'total_tracks': 19,
#   'available_markets': ['CA', 'US'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/34OkZVpuzBa9y40DCy0LPR'},
#   'href': 'https://api.spotify.com/v1/albums/34OkZVpuzBa9y40DCy0LPR',
#   'id': '34OkZVpuzBa9y40DCy0LPR',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273332d85510aba3eb28312cfb2',
#     'height': 640,
#     'width': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e02332d85510aba3eb28312cfb2',
#     'height': 300,
#     'width': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d00004851332d85510aba3eb28312cfb2',
#     'height': 64,
#     'width': 64}],
#   'name': '1989 (Deluxe Edition)',
#   'release_date': '2014-10-27',
#   'release_date_precision': 'day',
#   'type': 'album',
#   'uri': 'spotify:album:34OkZVpuzBa9y40DCy0LPR',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'album_group': 'album'}]

# %% [markdown]
# What is the data type?

# %%
type(albums)
# Out:
# list

# %% [markdown]
# Let's look at the first element

# %%
albums[0]
# Out:
# {'album_type': 'album',
#  'total_tracks': 31,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/5H7ixXZfsNMGbIE5OBSpcb'},
#  'href': 'https://api.spotify.com/v1/albums/5H7ixXZfsNMGbIE5OBSpcb',
#  'id': '5H7ixXZfsNMGbIE5OBSpcb',
#  'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2738ecc33f195df6aa257c39eaa',
#    'height': 640,
#    'width': 640},
#   {'url': 'https://i.scdn.co/image/ab67616d00001e028ecc33f195df6aa257c39eaa',
#    'height': 300,
#    'width': 300},
#   {'url': 'https://i.scdn.co/image/ab67616d000048518ecc33f195df6aa257c39eaa',
#    'height': 64,
#    'width': 64}],
#  'name': 'THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY',
#  'release_date': '2024-04-19',
#  'release_date_precision': 'day',
#  'type': 'album',
#  'uri': 'spotify:album:5H7ixXZfsNMGbIE5OBSpcb',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#    'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#    'id': '06HL4z0CvFAxyc27GXpf02',
#    'name': 'Taylor Swift',
#    'type': 'artist',
#    'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#  'album_group': 'album'}

# %% [markdown]
# * Each list element is another dictionary

# %%
albums[0]['name']
# Out:
# 'THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY'

# %%
albums[5]['name']
# Out:
# 'Midnights (The Til Dawn Edition)'

# %% [markdown]
# Now, let's make sure it gets all of the albums by iterating through all pages.

# %%
# sanity check -- please ignore
# results = spotify.artist_albums(taylor_uri, album_type='album')

# next_thing = results['next']
# print(next_thing)

# %%
while results['next']:
    results = spotify.next(results)
    albums.extend(results['items'])

# %% [markdown]
# Let's check the results!

# %%
for album in albums:
    print(album['name'])
# Out:
# THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY
# THE TORTURED POETS DEPARTMENT
# 1989 (Taylor's Version) [Deluxe]
# 1989 (Taylor's Version)
# Speak Now (Taylor's Version)
# Midnights (The Til Dawn Edition)
# Midnights (3am Edition)
# Midnights
# Red (Taylor's Version)
# Fearless (Taylor's Version)
# evermore (deluxe version)
# evermore
# folklore: the long pond studio sessions (from the Disney+ special) [deluxe edition]
# folklore (deluxe version)
# folklore
# Lover
# Taylor Swift Karaoke: reputation
# reputation
# reputation Stadium Tour Surprise Song Playlist
# 1989 (Deluxe Edition)
# 1989
# Red (Deluxe Edition)
# Red
# Speak Now World Tour Live
# Speak Now (Deluxe Edition)
# Speak Now
# Fearless Platinum Edition
# Fearless
# Live From Clear Channel Stripped 2008
# Taylor Swift

# %% [markdown]
# Now it's your turn! Play around with the Spotify API!

# %% [markdown]
# #### 1.1 Short in-class activity

# %% [markdown]
# 1. Get the name and release data of all the albums for your favorite artist on Spotify!
# 2. What is the oldest album of this artist?
#
# ***

# %% [markdown]
# ### 2. Google Maps API

# %% [markdown]
# 1. This uses the Google Developer Console.
#     - Navigate to: https://console.developers.google.com/apis/credentials?project=_
#     - Log in to your Google account
#     - Create a new project
#     - Create your credentials using the API key option (under +CREATE CREDENTIALS)
#     - Get your API Key
#     - Modify the api key in `start_google.py`
#     - Save file changes
#     - Go to library (in your developer console API and Services) and enable `Geocoding API` and `Distance Matrix API`

# %% [markdown]
# 2. Installation

# %% [markdown]
# Run the following into a Jupyter cell

# %%
import sys
print(sys.executable)
# Out:
# /usr/local/bin/python3

# %%
# !pip install googlemaps
# Out:
# Collecting googlemaps
#   Downloading googlemaps-4.10.0.tar.gz (33 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests<3.0,>=2.20.0 in /Users/claro/Library/Python/3.13/lib/python/site-packages (from googlemaps) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/claro/Library/Python/3.13/lib/python/site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/claro/Library/Python/3.13/lib/python/site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/claro/Library/Python/3.13/lib/python/site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/claro/Library/Python/3.13/lib/python/site-packages (from requests<3.0,>=2.20.0->googlemaps) (2025.8.3)
# Building wheels for collected packages: googlemaps
#   Building wheel for googlemaps (pyproject.toml) ... done
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40817 sha256=fc8ed0c6969f3cd320eddb50aa680c7ebcf93d943137c148f2d5b043012cd99e
#   Stored in directory: /Users/claro/Library/Caches/pip/wheels/76/2a/24/5993a7b77c9a37b86f415096436a448c1babdd132066bdcb31
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.10.0
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# 3. Import your credentials from start_google.py

# %%
# # sanity check -- please ignore
# import sys, site
# print("exe:", sys.executable)
# print("ENABLE_USER_SITE:", site.ENABLE_USER_SITE)
# print("usersite:", site.getusersitepackages())
# print("sys.path contains usersite?", site.getusersitepackages() in sys.path)
# print("sys.path:\n", "\n".join(sys.path))

# %%
import googlemaps

# api_key = "YOUR_API_KEY"
# client = googlemaps.Client(api_key)

# import importlib
# imported_items = importlib.import_module('start_google')

# %% [markdown]
# ##### Let's play around with it

# %% [markdown]
# * Copy client to an object named `gmaps`

# %%
import os
from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv("GOOGLE_API_KEY")

if not api_key:
    raise RuntimeError("GOOGLE_API_KEY not set in environment")

gmaps = googlemaps.Client(key=api_key)
gmaps

# gmaps = imported_items.client()

# %% [markdown]
# #### 2.1 Locating known places (no address)

# %% [markdown]
# ##### Locate The White House

# %% [markdown]
# * `location` is a list of many dictionaries nested into 1

# %%
whitehouse = 'The White House'
location = gmaps.geocode(whitehouse)
# location
location[0]['address_components']
# Out:
# [{'long_name': '1600', 'short_name': '1600', 'types': ['street_number']},
#  {'long_name': 'Pennsylvania Avenue Northwest',
#   'short_name': 'Pennsylvania Ave NW',
#   'types': ['route']},
#  {'long_name': 'Northwest Washington',
#   'short_name': 'Northwest Washington',
#   'types': ['neighborhood', 'political']},
#  {'long_name': 'Washington',
#   'short_name': 'Washington',
#   'types': ['locality', 'political']},
#  {'long_name': 'District of Columbia',
#   'short_name': 'DC',
#   'types': ['administrative_area_level_1', 'political']},
#  {'long_name': 'United States',
#   'short_name': 'US',
#   'types': ['country', 'political']},
#  {'long_name': '20500', 'short_name': '20500', 'types': ['postal_code']}]

# %% [markdown]
# * Get keys

# %%
location[0].keys()
# Out:
# dict_keys(['address_components', 'formatted_address', 'geometry', 'navigation_points', 'place_id', 'plus_code', 'types'])

# %% [markdown]
# * Get geometry

# %%
location[0]['geometry'].keys()
# Out:
# dict_keys(['location', 'location_type', 'viewport'])

# %% [markdown]
# * Get location

# %%
location[0]['geometry']['location']
# Out:
# {'lat': 38.8976763, 'lng': -77.0365298}

# %% [markdown]
# * Store info in object `latlong`

# %%
latlong = location[0]['geometry']['location']

# %% [markdown]
# * Get the destination using `latlong`

# %%
destination = gmaps.reverse_geocode(latlong)
destination
# Out:
# [{'address_components': [{'long_name': '1600',
#     'short_name': '1600',
#     'types': ['street_number']},
#    {'long_name': 'Pennsylvania Avenue Northwest',
#     'short_name': 'Pennsylvania Ave NW',
#     'types': ['route']},
#    {'long_name': 'Northwest Washington',
#     'short_name': 'Northwest Washington',
#     'types': ['neighborhood', 'political']},
#    {'long_name': 'Washington',
#     'short_name': 'Washington',
#     'types': ['locality', 'political']},
#    {'long_name': 'District of Columbia',
#     'short_name': 'DC',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']},
#    {'long_name': '20500', 'short_name': '20500', 'types': ['postal_code']}],
#   'formatted_address': '1600 Pennsylvania Ave NW, Washington, DC 20500, USA',
#   'geometry': {'location': {'lat': 38.8976763, 'lng': -77.0365298},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 38.8990252802915,
#      'lng': -77.0351808197085},
#     'southwest': {'lat': 38.8963273197085, 'lng': -77.0378787802915}}},
#   'navigation_points': [{'location': {'latitude': 38.8985201,
#      'longitude': -77.0365352},
#     'restricted_travel_modes': ['DRIVE']},
#    {'location': {'latitude': 38.9001305, 'longitude': -77.0365732},
#     'restricted_travel_modes': ['WALK']}],
#   'place_id': 'ChIJ37HL3ry3t4kRv3YLbdhpWXE',
#   'plus_code': {'compound_code': 'VXX7+39 Washington, DC, USA',
#    'global_code': '87C4VXX7+39'},
#   'types': ['establishment', 'point_of_interest', 'tourist_attraction']},
#  {'address_components': [{'long_name': '16000',
#     'short_name': '16000',
#     'types': ['street_number']},
#    {'long_name': 'Pennsylvania Avenue Northwest',
#     'short_name': 'Pennsylvania Ave NW',
#     'types': ['route']},
#    {'long_name': 'Northwest Washington',
#     'short_name': 'Northwest Washington',
#     'types': ['neighborhood', 'political']},
#    {'long_name': 'Washington',
#     'short_name': 'Washington',
#     'types': ['locality', 'political']},
#    {'long_name': 'District of Columbia',
#     'short_name': 'DC',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']},
#    {'long_name': '20500', 'short_name': '20500', 'types': ['postal_code']}],
#   'formatted_address': '16000 Pennsylvania Ave NW, Washington, DC 20500, USA',
#   'geometry': {'location': {'lat': 38.89771289999999, 'lng': -77.0365472},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 38.8990618802915,
#      'lng': -77.03519821970849},
#     'southwest': {'lat': 38.8963639197085, 'lng': -77.0378961802915}}},
#   'navigation_points': [{'location': {'latitude': 38.8978482,
#      'longitude': -77.0365423},
#     'restricted_travel_modes': ['DRIVE']},
#    {'location': {'latitude': 38.8975855, 'longitude': -77.0351448},
#     'restricted_travel_modes': ['WALK']}],
#   'place_id': 'ChIJv_BaqSq3t4kR1ZOAN67jtKE',
#   'plus_code': {'compound_code': 'VXX7+39 Washington, DC, USA',
#    'global_code': '87C4VXX7+39'},
#   'types': ['street_address', 'subpremise']},
#  {'address_components': [{'long_name': 'VXX7+39',
#     'short_name': 'VXX7+39',
#     'types': ['plus_code']},
#    {'long_name': 'Washington',
#     'short_name': 'Washington',
#     'types': ['locality', 'political']},
#    {'long_name': 'District of Columbia',
#     'short_name': 'District of Columbia',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'District of Columbia',
#     'short_name': 'DC',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']}],
#   'formatted_address': 'VXX7+39 Washington, DC, USA',
#   'geometry': {'bounds': {'northeast': {'lat': 38.89774999999999,
#      'lng': -77.03649999999999},
#     'southwest': {'lat': 38.897625, 'lng': -77.036625}},
#    'location': {'lat': 38.8976763, 'lng': -77.0365298},
#    'location_type': 'GEOMETRIC_CENTER',
#    'viewport': {'northeast': {'lat': 38.89903648029149,
#      'lng': -77.03521351970849},
#     'southwest': {'lat': 38.89633851970849, 'lng': -77.0379114802915}}},
#   'place_id': 'GhIJeHKXDudyQ0ARFRUWgVZCU8A',
#   'plus_code': {'compound_code': 'VXX7+39 Washington, DC, USA',
#    'global_code': '87C4VXX7+39'},
#   'types': ['plus_code']},
#  {'address_components': [{'long_name': 'Unnamed Road',
#     'short_name': 'Unnamed Road',
#     'types': ['route']},
#    {'long_name': 'Northwest Washington',
#     'short_name': 'Northwest Washington',
#     'types': ['neighborhood', 'political']},
#    {'long_name': 'Washington',
#     'short_name': 'Washington',
#     'types': ['locality', 'political']},
#    {'long_name': 'District of Columbia',
#     'short_name': 'DC',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']},
#    {'long_name': '20500', 'short_name': '20500', 'types': ['postal_code']}],
#   'formatted_address': 'Unnamed Road, Washington, DC 20500, USA',
#   'geometry': {'bounds': {'northeast': {'lat': 38.8979526, 'lng': -77.0362533},
#     'southwest': {'lat': 38.8979107, 'lng': -77.0366186}},
#    'location': {'lat': 38.8979177, 'lng': -77.03643319999999},
#    'location_type': 'GEOMETRIC_CENTER',
#    'viewport': {'northeast': {'lat': 38.8992806302915,
#      'lng': -77.03508696970849},
#     'southwest': {'lat': 38.8965826697085, 'lng': -77.03778493029151}}},
#   'place_id': 'ChIJgbXI4ry3t4kRxEmOU2Dkmjg',
#   'types': ['route']},
#  {'address_components': [{'long_name': '20500',
#     'short_name': '20500',
#     'types': ['postal_code']},
#    {'long_name': 'Northwest Washington',
#     'short_name': 'Northwest Washington',
#     'types': ['neighborhood', 'political']},
#    {'long_name': 'Washington',
#     'short_name': 'Washington',
#     'types': ['locality', 'political']},
#    {'long_name': 'District of Columbia',
#     'short_name': 'DC',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Washington, DC 20500, USA',
#   'geometry': {'bounds': {'northeast': {'lat': 38.8980424,
#      'lng': -77.03527249999999},
#     'southwest': {'lat': 38.8970971, 'lng': -77.0378229}},
#    'location': {'lat': 38.8975003, 'lng': -77.0364766},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 38.8989187302915,
#      'lng': -77.03519871970848},
#     'southwest': {'lat': 38.8962207697085, 'lng': -77.0378966802915}}},
#   'place_id': 'ChIJM98wTKK3t4kRCRVem9SdMqs',
#   'types': ['postal_code']},
#  {'address_components': [{'long_name': 'Northwest Washington',
#     'short_name': 'Northwest Washington',
#     'types': ['neighborhood', 'political']},
#    {'long_name': 'Washington',
#     'short_name': 'Washington',
#     'types': ['locality', 'political']},
#    {'long_name': '7',
#     'short_name': '7',
#     'types': ['administrative_area_level_3', 'political']},
#    {'long_name': 'District of Columbia',
#     'short_name': 'DC',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Northwest Washington, Washington, DC, USA',
#   'geometry': {'bounds': {'northeast': {'lat': 38.9955566, 'lng': -77.0060597},
#     'southwest': {'lat': 38.8891955, 'lng': -77.1197502}},
#    'location': {'lat': 38.9380912, 'lng': -77.04493269999999},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 38.9955566, 'lng': -77.0060597},
#     'southwest': {'lat': 38.8891955, 'lng': -77.1197502}}},
#   'place_id': 'ChIJi7U4CaS3t4kR0m_KoPJ00Bw',
#   'types': ['neighborhood', 'political']},
#  {'address_components': [{'long_name': 'Washington',
#     'short_name': 'Washington',
#     'types': ['locality', 'political']},
#    {'long_name': 'District of Columbia',
#     'short_name': 'District of Columbia',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'District of Columbia',
#     'short_name': 'DC',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Washington, DC, USA',
#   'geometry': {'bounds': {'northeast': {'lat': 38.9958641, 'lng': -76.909393},
#     'southwest': {'lat': 38.7916449, 'lng': -77.119759}},
#    'location': {'lat': 38.9071923, 'lng': -77.0368707},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 38.9958641, 'lng': -76.909393},
#     'southwest': {'lat': 38.7916449, 'lng': -77.119759}}},
#   'place_id': 'ChIJW-T2Wt7Gt4kRKl2I1CJFUsI',
#   'types': ['locality', 'political']},
#  {'address_components': [{'long_name': 'District of Columbia',
#     'short_name': 'DC',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Washington',
#     'short_name': 'Washington',
#     'types': ['locality', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Washington, DC, USA',
#   'geometry': {'bounds': {'northeast': {'lat': 38.995845, 'lng': -76.909393},
#     'southwest': {'lat': 38.791645, 'lng': -77.119759}},
#    'location': {'lat': 38.9059849, 'lng': -77.03341790000002},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 38.995845, 'lng': -76.909393},
#     'southwest': {'lat': 38.791645, 'lng': -77.119759}}},
#   'place_id': 'ChIJW-T2Wt7Gt4kRmKFUAsCO4tY',
#   'types': ['administrative_area_level_1', 'political']},
#  {'address_components': [{'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']}],
#   'formatted_address': 'United States',
#   'geometry': {'bounds': {'northeast': {'lat': 74.071038, 'lng': -66.885417},
#     'southwest': {'lat': 18.7763, 'lng': 166.9999999}},
#    'location': {'lat': 38.7945952, 'lng': -106.5348379},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 74.071038, 'lng': -66.885417},
#     'southwest': {'lat': 18.7763, 'lng': 166.9999999}}},
#   'place_id': 'ChIJCzYy5IS16lQRQrfeQ5K5Oxw',
#   'types': ['country', 'political']}]

# %% [markdown]
# * Sometimes you have to dig...

# %%
print(destination[0]["address_components"][1]['long_name'])
# Out:
# Pennsylvania Avenue Northwest

# %% [markdown]
# #### 2.2 Calculating distance with street address

# %% [markdown]
# ##### Find Duke University

# %%
duke = gmaps.geocode('326 Perkins Library, Durham, NC 27708')
duke_loc = duke[0]['geometry']['location']
duke_loc
# Out:
# {'lat': 36.0021437, 'lng': -78.93851490000002}

# %% [markdown]
# ##### Find WUSTL

# %%
washu = gmaps.geocode('1 Brookings Dr, St. Louis, MO 63130')
washu_loc = washu[0]['geometry']['location']
washu_loc
# Out:
# {'lat': 38.6482393, 'lng': -90.3015077}

# %% [markdown]
# * Find the distance (in km) between Duke and WUSTL

# %%
distance = gmaps.distance_matrix(duke_loc, washu_loc)
print(distance['rows'][0]['elements'][0]['distance']['text'])
# Out:
# 1,291 km

# %% [markdown]
# ##### 2.3 Plotting in Google Maps

# %% [markdown]
# * More information on: https://github.com/vgm64/gmplot
# * Run the following in a Jupyter cell:

# %%
# !pip install gmplot
# Out:
# Collecting gmplot
#   Downloading gmplot-1.4.1-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: requests in /Users/claro/Library/Python/3.13/lib/python/site-packages (from gmplot) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/claro/Library/Python/3.13/lib/python/site-packages (from requests->gmplot) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/claro/Library/Python/3.13/lib/python/site-packages (from requests->gmplot) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/claro/Library/Python/3.13/lib/python/site-packages (from requests->gmplot) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/claro/Library/Python/3.13/lib/python/site-packages (from requests->gmplot) (2025.8.3)
# Downloading gmplot-1.4.1-py3-none-any.whl (164 kB)
# Installing collected packages: gmplot
# Successfully installed gmplot-1.4.1
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# * Get St. Louis

# %%
from gmplot import gmplot

STL = gmaps.geocode('St. Louis')
STL[0]['geometry']['location']
latlongSTL = STL[0]['geometry']['location']

# %%
latlongSTL
# Out:
# {'lat': 38.62742799999999, 'lng': -90.1982439}

# %% [markdown]
# * Create plot area

# %%
plot1 = gmplot.GoogleMapPlotter(lat = latlongSTL['lat'], 
                                lng = latlongSTL['lng'],
                                zoom = 13, 
                                apikey = api_key)

# %% [markdown]
# * Create an object with places in STL

# %%
stl_places = ["Forest Park, St. Louis",
			"Missouri Botanical Garden, St. Louis",
			"Anheuser Busch, St. Louis",
			"Arch, St. Louis"]

# %% [markdown]
# * Create a function to find latlong for stl_places

# %%
def grab_latlng(place):
	x = gmaps.geocode(place)
	return (x[0]["geometry"]["location"]["lat"], x[0]["geometry"]["location"]["lng"])

# %% [markdown]
# * Run the function

# %%
l = [grab_latlng(i) for i in stl_places]
l
# Out:
# [(38.637152, -90.28579739999999),
#  (38.6127672, -90.25937979999999),
#  (38.62742799999999, -90.1982439),
#  (38.6251269, -90.1867504)]

# %% [markdown]
# ##### Built-in function `zip()`

# %% [markdown]
# * Use `zip()` to assign lat and long to different objects
# * `zip(*l )` means that the object `l` will be unpacked
# * Each of its elements will be returned separately

# %%
attraction_lats, attraction_lons = zip(*l)
# attraction_lats
attraction_lons
# Out:
# (-90.28579739999999, -90.25937979999999, -90.1982439, -90.1867504)

# %% [markdown]
# * Add points to our plot

# %%
plot1.scatter(lats = attraction_lats, 
			  lngs = attraction_lons,
			  color = 'black',
			  size = 40,
			  marker = True)

# %% [markdown]
# * Draw the plot

# %%
plot1.draw('/Users/claro/Desktop/PythonCamp2025/Day03/Day03_Part01/Lecture/my_map.html')

# %% [markdown]
# Tip: Here is a list of all public APIs:
# https://github.com/public-api-lists/public-api-lists
#
# Start thinking about what you want to do for your poster project!
#
# You could use any of the APIs that we cover in the course, or any APIs that you find interesting to get your data!
